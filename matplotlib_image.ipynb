# %% [markdown]
# <a href="https://colab.research.google.com/github/inuwamobarak/image-processing/blob/main/matplotlib_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROCESSING AND PLOTTING IMAGES

# %% [markdown]
# ## Using matplotlib
#
# We will process and plot image using Matplotlib backed with Pilow library. This is because Matplotlib relies on the Pillow library to load image data. We will be using Matplotlib's implicit plotting interface known as pyplot.
#
# We can use explicit plotting in building large application which is beyond this scope.

# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image #pilow

# %%
img = np.asarray(Image.open('/content/lexus.jpeg'))
print(repr(img))
# Out:
# array([[[152, 170, 110],
#         [150, 166, 104],
#         [133, 147,  85],
#         ...,
#         [237, 238, 240],
#         [237, 238, 240],
#         [237, 238, 240]],
#
#        [[171, 189, 129],
#         [147, 162, 103],
#         [125, 139,  78],
#         ...,
#         [237, 238, 240],
#         [237, 238, 240],
#         [237, 238, 240]],
#
#        [[213, 228, 173],
#         [160, 175, 118],
#         [129, 143,  84],
#         ...,
#         [236, 237, 239],
#         [236, 237, 239],
#         [236, 237, 239]],
#
#        ...,
#
#        [[205, 186, 169],
#         [204, 185, 168],
#         [191, 172, 155],
#         ...,
#         [172, 151, 124],
#         [188, 167, 140],
#         [208, 187, 160]],
#
#        [[188, 169, 152],
#         [191, 172, 155],
#         [189, 170, 153],
#         ...,
#         [211, 190, 163],
#         [205, 184, 157],
#         [206, 185, 158]],
#
#        [[197, 178, 161],
#         [195, 176, 159],
#         [194, 175, 158],
# ...

# %% [markdown]
# Note: dtype=unit8 is added at the end due to the repr added to the print image

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img_dimention = img.shape
print("Printing Image dimention...")
img_dimention
# Out:
# Printing Image dimention...
# (960, 1280, 3)

# %% [markdown]
# # Plotting Numpy Arrays as images
#
# We have added the image as a numpy array by generating it.

# %% [markdown]
# Matplotlib performs image plotting using the imshow() function.

# %%
img_plot = plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Applying Pseudocolor Schemes to image plots

# %% [markdown]
# Pseudocolor helps to enhance image contrast and visualization.
#
# We currently have an RGB image. Since R, G, and B are all similar , we can just pick one channel of our data using array slicing (you can read more in the Numpy tutorial):

# %%
lum_img = img[:, :, 0]
plt.imshow(lum_img)

# %% [markdown]
# We can also change the colormap as shown below.

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('inferno')

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('seismic')

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('PuBuGn')

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('tab10')

# %% [markdown]
# # Color Scale Reference
#
# The value of the image colours can be represented on a color bar.

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %% [markdown]
# # Array Interpolation schemes
#
# Interpolation calculates what the color or value of a pixel "should" be, according to different mathematical schemes.
#
# When an image size is compressed or shrinked together, (Not croped), the scheme tries to still maintain the image looks by using the original appearance.
#
# Even though the pixels are adjusted, the coputer adjust the few pixels available to fill that space.

# %%
# Using pilow
img = Image.open('lexus.jpeg') # re-loading our image
img.thumbnail((64, 64))  # resizes image in-place / shrinking image to 64 pixels
imgplot = plt.imshow(img) # displays the default type of interpolation "nearest"

# %%
imgplot = plt.imshow(img, interpolation="bilinear") # Changing the default interpolation

# %%
imgplot = plt.imshow(img, interpolation="bicubic")
